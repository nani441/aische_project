# %%
# Importing the libraries 

import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# Ignore harmless warnings 


import warnings 
warnings.filterwarnings("ignore")

# Set to display all the columns in dataset

pd.set_option("display.max_columns", None)

# Import psql to run queries 

import pandasql as psql

# %%
df1 = pd.read_csv(r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\project.csv')

# %%
df1
# Out:
#        Institute ID                                               Name  \
# 0    IR17-I-2-18243              Indian Institute of Science Bangalore
# 1    IR17-I-2-1-319                        Jawaharlal Nehru University
# 2    IR17-I-2-18500                           Banaras Hindu University
# 3    IR17-I-2-30673  Jawaharlal Nehru Centre for Advanced Scientifi...
# 4    IR17-I-2-10326                                Jadavpur University
# ..              ...                                                ...
# 495     IR-O-U-0121                                     Goa University
# 496     IR-O-U-0043  Vignan's Foundation for Science, Technology an...
# 497     IR-O-U-0555                             Graphic Era University
# 498     IR-O-U-0223                                    Jain University
# 499     IR-O-U-0564         University of Petroleum and Energy Studies
#
#           City           State  infra  placements  academic  Year branch  \
# ...

# %%
df1.describe()
# Out:
#             infra  placements    academic        Year        Rank
# count  500.000000  500.000000  500.000000   500.00000  500.000000
# mean    19.604140   70.248000   45.946420  2019.00000   50.500000
# std     17.372008   54.832287    8.060343     1.41563   28.894979
# min      0.000000    1.000000   32.990000  2017.00000    1.000000
# 25%      4.700000   27.000000   40.240000  2018.00000   25.750000
# 50%     16.585000   58.500000   44.065000  2019.00000   50.500000
# 75%     30.700000  100.000000   50.077500  2020.00000   75.250000
# max    100.000000  243.000000   84.180000  2021.00000  100.000000

# %%
df1.isnull().sum() #returns the number of missing values in the data set
# Out:
# Institute ID    0
# Name            0
# City            0
# State           0
# infra           0
# placements      0
# academic        0
# Year            0
# branch          0
# gender          0
# Rank            0
# dtype: int64

# %%
len_I = df1['Institute ID'].unique() #used to find the unique elements of an array

# %%
len(len_I)
# Out:
# 324

# %%
list_N = df1['Name'].unique()

# %%
len(list_N)
# Out:
# 177

# %%
df1.drop('Institute ID',axis=1,inplace=True) #The drop() method removes the specified row or column.

# %%
df1.drop('branch',axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        500 non-null    object
#  1   City        500 non-null    object
#  2   State       500 non-null    object
#  3   infra       500 non-null    float64
#  4   placements  500 non-null    int64
#  5   academic    500 non-null    float64
#  6   Year        500 non-null    int64
#  7   gender      500 non-null    object
#  8   Rank        500 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 35.3+ KB

# %%
df_2017 = df1[df1['Year']==2017]

# %%
df_2017
# Out:
#                                                  Name       City  \
# 0               Indian Institute of Science Bangalore  Bengaluru
# 1                         Jawaharlal Nehru University  New Delhi
# 2                            Banaras Hindu University   Varanasi
# 3   Jawaharlal Nehru Centre for Advanced Scientifi...  Bengaluru
# 4                                 Jadavpur University    Kolkata
# ..                                                ...        ...
# 95                     Sri Krishnadevaraya University  Anantapur
# 96                                Alagappa University  Karaikudi
# 97  Narsee Monjee Institute of Management Studies ...     Mumbai
# 98          Jawaharlal Nehru Technological University   Kakinada
# 99  B.S. Abdur Rahman Institute of Science and Tec...    Chennai
#
#              State  infra  placements  academic  Year gender  Rank
# 0        Karnataka  83.33           1     52.74  2017   coed     1
# ...

# %%
df_2018 = df1[df1['Year']==2018]

# %%
df_2018
# Out:
#                                                   Name        City  \
# 100              Indian Institute of Science Bangalore   Bengaluru
# 101                        Jawaharlal Nehru University   New Delhi
# 102                           Banaras Hindu University    Varanasi
# 103                                    Anna University     Chennai
# 104                            University of Hyderabad   Hyderabad
# ..                                                 ...         ...
# 195                          The University of Burdwan  Barddhaman
# 196                    D. Y. Patil Educational Society    Kolhapur
# 197  International Institute of Information Technology   Hyderabad
# 198                                     PES University   Bengaluru
# 199         Jaypee Institute of Information Technology       Noida
#
#              State   infra  placements  academic  Year gender  Rank
# 100      Karnataka  100.00           1     82.16  2018   coed     1
# ...

# %%
df_2019 = df1[df1['Year']==2019]

# %%
df_2019
# Out:
#                                                   Name         City  \
# 200              Indian Institute of Science Bangalore    Bengaluru
# 201                        Jawaharlal Nehru University    New Delhi
# 202                           Banaras Hindu University     Varanasi
# 203                            University of Hyderabad    Hyderabad
# 204                                Calcutta University      Kolkata
# ..                                                 ...          ...
# 295                       Central University of Punjab     Bathinda
# 296                           Assam University-Silchar      Silchar
# 297                             Kurukshetra University  Kurukshetra
# 298                            Rajiv Gandhi University     Itanagar
# 299  Meenakshi Academy of Higher Education and Rese...      Chennai
#
#                  State   infra  placements  academic  Year gender  Rank
# 200          Karnataka  100.00           1     82.28  2019   coed     1
# ...

# %%
df_2020 = df1[df1['Year']==2020]

# %%
df_2020
# Out:
#                                                   Name                  City  \
# 300              Indian Institute of Science Bangalore             Bengaluru
# 301                        Jawaharlal Nehru University             New Delhi
# 302                           Banaras Hindu University              Varanasi
# 303                         Amrita Vishwa Vidyapeetham            Coimbatore
# 304                                Jadavpur University               Kolkata
# ..                                                 ...                   ...
# 395                                   Utkal University           Bhubaneswar
# 396                             Graphic Era University              Dehradun
# 397        Chettinad Academy of Research and Education  Kanchipuram District
# 398                             Kurukshetra University           Kurukshetra
# 399  Vignan's Foundation for Science, Technology & ...                Guntur
#
# ...

# %%
df_2021 = df1[df1['Year']==2021]

# %%
df_2021
# Out:
#                                                   Name        City  \
# 400              Indian Institute of Science Bangalore   Bengaluru
# 401                        Jawaharlal Nehru University   New Delhi
# 402                           Banaras Hindu University    Varanasi
# 403                                Calcutta University     Kolkata
# 404                         Amrita Vishwa Vidyapeetham  Coimbatore
# ..                                                 ...         ...
# 495                                     Goa University         Goa
# 496  Vignan's Foundation for Science, Technology an...      Guntur
# 497                             Graphic Era University    Dehradun
# 498                                    Jain University    Bengluru
# 499         University of Petroleum and Energy Studies    Dehradun
#
#               State   infra  placements  academic  Year gender  Rank
# 400       Karnataka  100.00           1     82.67  2021  women     1
# ...

# %%
df_suffix = pd.merge(df_2017, df_2018, left_on='Name',right_on='Name',how='outer',suffixes=('_2017','_2018'))

df_suffix
# Out:
#                                                   Name  City_2017  \
# 0                Indian Institute of Science Bangalore  Bengaluru
# 1                          Jawaharlal Nehru University  New Delhi
# 2                             Banaras Hindu University   Varanasi
# 3    Jawaharlal Nehru Centre for Advanced Scientifi...  Bengaluru
# 4                                  Jadavpur University    Kolkata
# ..                                                 ...        ...
# 127                                           Yenepoya        NaN
# 128                                Nagaland University        NaN
# 129                          The University of Burdwan        NaN
# 130                    D. Y. Patil Educational Society        NaN
# 131  International Institute of Information Technology        NaN
#
#         State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0        Karnataka       83.33              1.0          52.74     2017.0
# ...

# %%
df_suffix.isna().sum()# returns the number of missing values in each column.
# Out:
# Name                0
# City_2017          32
# State_2017         32
# infra_2017         32
# placements_2017    32
# academic_2017      32
# Year_2017          32
# gender_2017        32
# Rank_2017          32
# City_2018          32
# State_2018         32
# infra_2018         32
# placements_2018    32
# academic_2018      32
# Year_2018          32
# gender_2018        32
# Rank_2018          32
# dtype: int64

# %%
df_suffix['infra_2017'].describe()
# Out:
# count    100.000000
# mean      10.840900
# std       13.184734
# min        0.020000
# 25%        2.715000
# 50%        5.960000
# 75%       14.450000
# max       83.330000
# Name: infra_2017, dtype: float64

# %%
df_suffix['placements_2017'].fillna(14.5,inplace=True)

# %%
df_suffix['academic_2017'].describe()
# Out:
# count    100.000000
# mean      41.926300
# std        8.007775
# min       32.990000
# 25%       36.195000
# 50%       39.820000
# 75%       44.867500
# max       83.280000
# Name: academic_2017, dtype: float64

# %%
df_suffix['infra_2017'].describe()
# Out:
# count    100.000000
# mean      10.840900
# std       13.184734
# min        0.020000
# 25%        2.715000
# 50%        5.960000
# 75%       14.450000
# max       83.330000
# Name: infra_2017, dtype: float64

# %%
df_data = pd.merge(df_2017, df_2018, on='Name',suffixes=('_2017','_2018'))

# %%
df_data
# Out:
#                                            Name        City_2017  \
# 0         Indian Institute of Science Bangalore        Bengaluru
# 1                   Jawaharlal Nehru University        New Delhi
# 2                      Banaras Hindu University         Varanasi
# 3                           Jadavpur University          Kolkata
# 4                               Anna University          Chennai
# ..                                          ...              ...
# 63  Cochin University of Science and Technology           Cochin
# 64                     Bharathidasan University  Tiruchirappalli
# 65                     Assam University-Silchar          Silchar
# 66                               PES University        Bengaluru
# 67                          Alagappa University        Karaikudi
#
#        State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0       Karnataka       83.33                1          52.74       2017
# ...

# %%
df_data_1920 = pd.merge(df_data,df_2019,on='Name',suffixes=('','_2019'))

# %%
df_data_1920
# Out:
#                                            Name        City_2017  \
# 0         Indian Institute of Science Bangalore        Bengaluru
# 1                   Jawaharlal Nehru University        New Delhi
# 2                      Banaras Hindu University         Varanasi
# 3                           Jadavpur University          Kolkata
# 4                               Anna University          Chennai
# ..                                          ...              ...
# 59                           Periyar University            Salem
# 60  Cochin University of Science and Technology           Cochin
# 61                     Bharathidasan University  Tiruchirappalli
# 62                     Assam University-Silchar          Silchar
# 63                          Alagappa University        Karaikudi
#
#        State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0       Karnataka       83.33                1          52.74       2017
# ...

# %%
df_data_20 = pd.merge(df_data_1920,df_2020,on='Name',suffixes=('','_2020'))

# %%
df_data_20
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_20
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_check = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_check
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_21 = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_21
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_21.drop('Name',inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop(['Year_2017','Year_2018','Year_2020','Year_2021'],inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop('Year',inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop(['Rank_2021','placements_2021','academic_2021'],inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
X = df_data_21.drop('infra_2021',axis=1)

# %%
X
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in X.columns:
    if X[col].dtypes == 'object':
        X[col] = le.fit_transform(X[col])

# %%
y = df_data_21['infra_2020']

# %%
y
# Out:
# 0     100.00
# 1      67.24
# 2      53.99
# 3      71.44
# 4      65.89
# 5      58.32
# 6      53.44
# 7      44.33
# 8      44.99
# 9      38.99
# 10     31.60
# 11     49.00
# 12     47.99
# 13     43.95
# 14     19.30
# 15     33.54
# 16     21.87
# 17     39.00
# 18     44.07
# 19     23.16
# 20     22.20
# 21     37.18
# 22     21.54
# 23     34.88
# 24     42.39
# 25     28.88
# 26     38.30
# 27     37.00
# 28     39.82
# 29     19.47
# 30     33.54
# 31     23.48
# 32     31.30
# 33     30.10
# 34     20.18
# 35     39.00
# 36     19.11
# 37     21.21
# 38     21.54
# 39     28.20
# 40     31.47
# 41     30.70
# 42     25.82
# 43     35.48
# 44      4.53
# 45     18.74
# 46     22.85
# 47     28.09
# 48     29.39
# 49     40.09
# 50     44.76
# Name: infra_2020, dtype: float64

# %%
'''Scikit-learn (Sklearn) is the most useful and robust library for machine learning in Python. 
It provides a selection of efficient tools for machine learning and statistical modeling including classification, 
regression, clustering and dimensionality
reduction via a consistence interface in Python.'''
# Out:
# 'Scikit-learn (Sklearn) is the most useful and robust library for machine learning in Python. \nIt provides a selection of efficient tools for machine learning and statistical modeling including classification, \nregression, clustering and dimensionality\nreduction via a consistence interface in Python.'

# %%
from sklearn.model_selection import train_test_split#Model_selection is a method for setting a blueprint to analyze data and then using it to measure new data.

X_train, X_test, Y_train, Y_test = train_test_split(X,y, random_state=101)

# %%
X_train
# Out:
#     City_2017  State_2017  infra_2017  placements_2017  academic_2017  \
# 46         21           5        3.95               79          35.50
# 18         23           7       20.69               16          44.95
# 3          20          16       28.81                9          51.20
# 41          0          15       15.65               22          36.36
# 30         26           7       11.61               33          40.59
# 15         23           7        8.70               47          46.45
# 20         16           1        2.48              102          44.42
# 44         14           3        3.37               90          35.60
# 38         10          15        5.24               66          37.95
# 45         25          10        4.34               74          35.50
# 39          4           5        0.69              141          37.25
# 10         24           3        9.73               42          61.53
# ...

# %%
X_test
# Out:
#     City_2017  State_2017  infra_2017  placements_2017  academic_2017  \
# 37          7           6        4.74               68          38.45
# 14         20          16        4.71               69          54.70
# 21         12          13        9.11               45          44.29
# 32          6           9       20.95               14          40.47
# 22         31           6        0.89              132          43.95
# 1          24           3       47.27                3          51.75
# 26          9          13       10.82               40          41.85
# 47         27          13        5.85               61          35.44
# 43          2          11        4.65               71          35.83
# 48         11           6        1.89              109          35.42
# 16          9          13        3.79               84          46.45
# 24          8           2       18.99               18          43.13
# ...

# %%
Y_train
# Out:
# 46     22.85
# 18     44.07
# 3      71.44
# 41     30.70
# 30     33.54
# 15     33.54
# 20     22.20
# 44      4.53
# 38     21.54
# 45     18.74
# 39     28.20
# 10     31.60
# 50     44.76
# 25     28.88
# 33     30.10
# 36     19.11
# 2      53.99
# 27     37.00
# 34     20.18
# 35     39.00
# 8      44.99
# 19     23.16
# 29     19.47
# 12     47.99
# 5      58.32
# 0     100.00
# 28     39.82
# 42     25.82
# 4      65.89
# 40     31.47
# 13     43.95
# 9      38.99
# 49     40.09
# 23     34.88
# 6      53.44
# 17     39.00
# 11     49.00
# 31     23.48
# Name: infra_2020, dtype: float64

# %%
Y_test
# Out:
# 37    21.21
# 14    19.30
# 21    37.18
# 32    31.30
# 22    21.54
# 1     67.24
# 26    38.30
# 47    28.09
# 43    35.48
# 48    29.39
# 16    21.87
# 24    42.39
# 7     44.33
# Name: infra_2020, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler #StandardScaler removes the mean and scales each feature/variable to unit variance.
sc = StandardScaler()

# %%
X_train_std = sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[ 0.15450786, -0.71810926, -0.70547544, ...,  0.10796939,
#         -0.71810926, -0.72111026],
#        [ 0.36051834, -0.32827852,  0.32267485, ...,  0.31311123,
#         -0.32827852,  1.38675049],
#        [ 0.05150262,  1.42595982,  0.8213953 , ..., -0.09717245,
#          1.42595982, -0.72111026],
#        ...,
#        [-0.2575131 ,  1.03612908, -0.26264608, ..., -0.40488522,
#          1.03612908, -0.72111026],
#        [ 1.59658123,  0.8412137 ,  1.07566903, ...,  1.64653321,
#          0.8412137 , -0.72111026],
#        [ 0.87554454, -0.13336315, -0.74908277, ...,  0.92853676,
#         -0.13336315, -0.72111026]])

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-1.28756551, -0.52319389, -0.65695461,  0.35702913, -0.65686469,
#         -0.47519096,  0.6381666 ,  0.03317957, -0.52319389, -0.55372166,
#          0.00930444, -1.05264908, -0.4330127 ,  1.57090715,  0.00539847,
#         -0.52319389, -0.58358586,  0.08871385, -0.91056647, -0.47519096,
#          1.19950797,  0.00539847, -0.52319389, -0.93084868,  0.9977475 ,
#         -0.6654063 , -0.55708601,  0.70185884,  0.00539847, -0.52319389,
#         -0.72111026],
#        [ 0.05150262,  1.42595982, -0.65879717,  0.3791976 ,  1.06395303,
#         -0.47519096, -0.74965353, -0.07188907,  1.42595982, -0.5908479 ,
#          0.15073192, -0.20061192, -0.4330127 , -0.20470745,  0.82596584,
#          1.42595982, -0.37278954, -0.22617157, -0.45466114, -0.47519096,
#          0.08171035,  0.82596584,  1.42595982, -1.04164982,  1.54753809,
#         -0.61039215,  1.79505494,  0.54450996,  0.82596584,  1.42595982,
#         -0.72111026],
# ...

# %%
X_train_std
# Out:
# array([[ 0.15450786, -0.71810926, -0.70547544, ...,  0.10796939,
#         -0.71810926, -0.72111026],
#        [ 0.36051834, -0.32827852,  0.32267485, ...,  0.31311123,
#         -0.32827852,  1.38675049],
#        [ 0.05150262,  1.42595982,  0.8213953 , ..., -0.09717245,
#          1.42595982, -0.72111026],
#        ...,
#        [-0.2575131 ,  1.03612908, -0.26264608, ..., -0.40488522,
#          1.03612908, -0.72111026],
#        [ 1.59658123,  0.8412137 ,  1.07566903, ...,  1.64653321,
#          0.8412137 , -0.72111026],
#        [ 0.87554454, -0.13336315, -0.74908277, ...,  0.92853676,
#         -0.13336315, -0.72111026]])

# %%
X_test_std
# Out:
# array([[-1.28756551, -0.52319389, -0.65695461,  0.35702913, -0.65686469,
#         -0.47519096,  0.6381666 ,  0.03317957, -0.52319389, -0.55372166,
#          0.00930444, -1.05264908, -0.4330127 ,  1.57090715,  0.00539847,
#         -0.52319389, -0.58358586,  0.08871385, -0.91056647, -0.47519096,
#          1.19950797,  0.00539847, -0.52319389, -0.93084868,  0.9977475 ,
#         -0.6654063 , -0.55708601,  0.70185884,  0.00539847, -0.52319389,
#         -0.72111026],
#        [ 0.05150262,  1.42595982, -0.65879717,  0.3791976 ,  1.06395303,
#         -0.47519096, -0.74965353, -0.07188907,  1.42595982, -0.5908479 ,
#          0.15073192, -0.20061192, -0.4330127 , -0.20470745,  0.82596584,
#          1.42595982, -0.37278954, -0.22617157, -0.45466114, -0.47519096,
#          0.08171035,  0.82596584,  1.42595982, -1.04164982,  1.54753809,
#         -0.61039215,  1.79505494,  0.54450996,  0.82596584,  1.42595982,
#         -0.72111026],
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([20.7688, 20.6131, 41.0385, 31.2916, 23.3067, 68.0601, 40.5151,
#        26.6372, 34.5   , 29.3064, 21.1259, 44.5355, 49.9065])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9684762063868722

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City_2017        51 non-null     int32
#  1   State_2017       51 non-null     int32
#  2   infra_2017       51 non-null     float64
#  3   placements_2017  51 non-null     int64
#  4   academic_2017    51 non-null     float64
#  5   gender_2017      51 non-null     int32
#  6   Rank_2017        51 non-null     int64
#  7   City_2018        51 non-null     int32
#  8   State_2018       51 non-null     int32
#  9   infra_2018       51 non-null     float64
#  10  placements_2018  51 non-null     int64
#  11  academic_2018    51 non-null     float64
#  12  gender_2018      51 non-null     int32
#  13  Rank_2018        51 non-null     int64
#  14  City             51 non-null     int32
#  15  State            51 non-null     int32
#  16  infra            51 non-null     float64
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred_d = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred_d)
# Out:
# 0.9843292783296231

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, Y_train)
# Out:
# SVR()

# %%
y_pred_s = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred_s)
# Out:
# 0.46194941661022204

# %%
import joblib
joblib.dump(regressor,r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\dcr.sav')
# Out:
# ['C:\\Users\\Narasimha Reddy\\OneDrive\\Desktop\\sih\\model\\dcr.sav']

# %%
model= joblib.load(r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\dcr.sav')

# %%
model.predict(X_test)
# Out:
# array([30.34430272, 31.26865449, 39.33660811, 35.42306211, 31.90252069,
#        42.10570225, 39.08912897, 32.49460951, 32.7238367 , 32.60137666,
#        29.88731713, 39.71335477, 41.18921997])

# %%
yy = model.predict(X)

# %%
from sklearn.metrics import r2_score
r2_score(y, yy)
# Out:
# 0.35966752818782066

# %%
model.predict(X)
# Out:
# array([39.6615783 , 42.10570225, 42.01064258, 42.09671553, 41.74322582,
#        41.63769502, 41.6151886 , 41.18921997, 39.94460674, 39.09000009,
#        37.77368558, 41.54992268, 41.33929233, 41.24950111, 31.26865449,
#        35.41112178, 29.88731713, 36.78218005, 40.26928811, 31.28161848,
#        31.19820343, 39.33660811, 31.90252069, 36.94328372, 39.71335477,
#        34.26700115, 39.08912897, 32.70298548, 38.93172866, 29.70309497,
#        33.44000002, 30.86346101, 35.42306211, 33.70334399, 29.51152763,
#        36.6761832 , 30.26944901, 30.34430272, 30.83921314, 30.22433002,
#        31.03829717, 33.57676241, 31.73745848, 32.7238367 , 30.4516005 ,
#        31.25560435, 30.57278688, 32.49460951, 32.60137666, 36.65464811,
#        37.12794134])

# %%
yk = model.predict(X)

# %%
yk
# Out:
# array([39.6615783 , 42.10570225, 42.01064258, 42.09671553, 41.74322582,
#        41.63769502, 41.6151886 , 41.18921997, 39.94460674, 39.09000009,
#        37.77368558, 41.54992268, 41.33929233, 41.24950111, 31.26865449,
#        35.41112178, 29.88731713, 36.78218005, 40.26928811, 31.28161848,
#        31.19820343, 39.33660811, 31.90252069, 36.94328372, 39.71335477,
#        34.26700115, 39.08912897, 32.70298548, 38.93172866, 29.70309497,
#        33.44000002, 30.86346101, 35.42306211, 33.70334399, 29.51152763,
#        36.6761832 , 30.26944901, 30.34430272, 30.83921314, 30.22433002,
#        31.03829717, 33.57676241, 31.73745848, 32.7238367 , 30.4516005 ,
#        31.25560435, 30.57278688, 32.49460951, 32.60137666, 36.65464811,
#        37.12794134])

# %%
l_check = df_data_check['Name'].tolist()

# %%
gen=df_data_check['gender'].tolist()
gen
# Out:
# ['coed',
#  'coed',
#  'coed',
#  'women',
#  'women',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'coed',
#  'women',
#  'coed',
#  'coed',
#  'coed',
#  'women',
#  'coed']

# %%
l_check
# Out:
# ['Indian Institute of Science Bangalore',
#  'Jawaharlal Nehru University',
#  'Banaras Hindu University',
#  'Jadavpur University',
#  'Anna University',
#  'University of Hyderabad',
#  'University of Delhi',
#  'Amrita Vishwa Vidyapeetham',
#  'Savitribai Phule Pune University',
#  'Aligarh Muslim University',
#  'Jamia Millia Islamia',
#  'Vellore Institute of Technology',
#  'Calcutta University',
#  'Manipal Academy of Higher Education-Manipal',
#  'Visva Bharati',
#  'Homi Bhabha National Institute',
#  'Bharath Institute of Higher Education & Research',
#  'Osmania University',
#  'Institute of Chemical Technology',
#  'Jamia Hamdard',
#  'Gauhati University',
#  'Bharathiar University',
#  'Kerala University',
#  'Tezpur University',
#  'Panjab University',
#  'Pondicherry University',
#  'University of Madras',
#  'Sri Venkateswara University',
#  'Andhra University',
#  'Sathyabama Institute of Science and Technology',
#  'Dr. D. Y. Patil Vidyapeeth Pune',
# ...

# %%
percentile_list = pd.DataFrame({'Name' : [l_check],
                                'infra' : [yk],
                                'Gender':[gen]})

# %%
percentile_list
# Out:
#                                                 Name  \
# 0  [Indian Institute of Science Bangalore, Jawaha...
#
#                                                infra  \
# 0  [39.66157830277012, 42.105702253687156, 42.010...
#
#                                               Gender
# 0  [coed, coed, coed, women, women, coed, coed, w...

# %%
dd_check = pd.DataFrame(list(zip(l_check,yk,gen)),
              columns=['Name','infra','gender'])

# %%
dd_check
# Out:
#                                                  Name      infra gender
# 0               Indian Institute of Science Bangalore  39.661578   coed
# 1                         Jawaharlal Nehru University  42.105702   coed
# 2                            Banaras Hindu University  42.010643   coed
# 3                                 Jadavpur University  42.096716  women
# 4                                     Anna University  41.743226  women
# 5                             University of Hyderabad  41.637695   coed
# 6                                 University of Delhi  41.615189   coed
# 7                          Amrita Vishwa Vidyapeetham  41.189220  women
# 8                    Savitribai Phule Pune University  39.944607   coed
# 9                           Aligarh Muslim University  39.090000   coed
# 10                               Jamia Millia Islamia  37.773686   coed
# 11                    Vellore Institute of Technology  41.549923  women
# ...

# %%
dd_check.sort_values(by=['infra'])
# Out:
#                                                  Name      infra gender
# 34                               Banasthali Vidyapith  29.511528   coed
# 29     Sathyabama Institute of Science and Technology  29.703095   coed
# 16   Bharath Institute of Higher Education & Research  29.887317   coed
# 39       KLE Academy of Higher Education and Research  30.224330   coed
# 36  Saveetha Institute of Medical and Technical Sc...  30.269449   coed
# 37                                 Calicut University  30.344303   coed
# 44          Guru Gobind Singh Indraprastha University  30.451600   coed
# 46                                   NITTE University  30.572787   coed
# 38                              Shiv Nadar University  30.839213   coed
# 31                      North Eastern Hill University  30.863461   coed
# 40                                University of Jammu  31.038297   coed
# 20                                 Gauhati University  31.198203   coed
# ...

# %%
df_data_ck = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_ck
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_ck.drop(['Year_2017','Year_2018','Year_2020','Year_2021','Year'],inplace=True,axis=1)

# %%
df_data_ck
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_ck.drop(['infra_2017','placements_2017', 'academic_2017','Rank_2017'],inplace=True,axis=1)

# %%
df_data_ck
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
X=df_data_ck.drop('Name',axis=1)

# %%
X
# Out:
#              City_2017         State_2017 gender_2017           City_2018  \
# 0            Bengaluru          Karnataka        coed           Bengaluru
# 1            New Delhi              Delhi        coed           New Delhi
# 2             Varanasi      Uttar Pradesh        coed            Varanasi
# 3              Kolkata        West Bengal        coed             Kolkata
# 4              Chennai         Tamil Nadu        coed             Chennai
# 5            Hyderabad          Telangana        coed           Hyderabad
# 6                Delhi              Delhi        coed               Delhi
# 7           Coimbatore         Tamil Nadu        coed          Coimbatore
# 8                 Pune        Maharashtra        coed                Pune
# 9              Aligarh      Uttar Pradesh       women             Aligarh
# 10           New Delhi              Delhi       women           New Delhi
# 11             Vellore         Tamil Nadu        coed             Vellore
# ...

# %%
X.columns
# Out:
# Index(['City_2017', 'State_2017', 'gender_2017', 'City_2018', 'State_2018',
#        'infra_2018', 'placements_2018', 'academic_2018', 'gender_2018',
#        'Rank_2018', 'City', 'State', 'infra', 'placements', 'academic',
#        'gender', 'Rank', 'City_2020', 'State_2020', 'infra_2020',
#        'placements_2020', 'academic_2020', 'gender_2020', 'Rank_2020',
#        'City_2021', 'State_2021', 'infra_2021', 'placements_2021',
#        'academic_2021', 'gender_2021', 'Rank_2021'],
#       dtype='object')

# %%
df_data_21.columns
# Out:
# Index(['City_2017', 'State_2017', 'infra_2017', 'placements_2017',
#        'academic_2017', 'gender_2017', 'Rank_2017', 'City_2018', 'State_2018',
#        'infra_2018', 'placements_2018', 'academic_2018', 'gender_2018',
#        'Rank_2018', 'City', 'State', 'infra', 'placements', 'academic',
#        'gender', 'Rank', 'City_2020', 'State_2020', 'infra_2020',
#        'placements_2020', 'academic_2020', 'gender_2020', 'Rank_2020',
#        'City_2021', 'State_2021', 'infra_2021', 'gender_2021'],
#       dtype='object')

# %%
X.rename(columns = {'infra_2018':'infra_2017', 'placements_2018':'placements_2017',
                    'academic_2018':'academic_2017', 'Rank_2018':'Rank_2017',
                   'infra':'infra_2018', 'placements':'placements_2018',
                   'academic':'academic_2018', 'Rank':'Rank_2018',
                   'infra_2020':'infra', 'placements_2020':'placements',
                   'academic_2020':'academic', 'Rank_2020':'Rank',
                   'infra_2021':'infra_2020', 'placements_2021':'placements_2020',
                   'academic_2021':'academic_2020', 'Rank_2021':'Rank_2020'}, inplace = True)

# %%
X
# Out:
#              City_2017         State_2017 gender_2017           City_2018  \
# 0            Bengaluru          Karnataka        coed           Bengaluru
# 1            New Delhi              Delhi        coed           New Delhi
# 2             Varanasi      Uttar Pradesh        coed            Varanasi
# 3              Kolkata        West Bengal        coed             Kolkata
# 4              Chennai         Tamil Nadu        coed             Chennai
# 5            Hyderabad          Telangana        coed           Hyderabad
# 6                Delhi              Delhi        coed               Delhi
# 7           Coimbatore         Tamil Nadu        coed          Coimbatore
# 8                 Pune        Maharashtra        coed                Pune
# 9              Aligarh      Uttar Pradesh       women             Aligarh
# 10           New Delhi              Delhi       women           New Delhi
# 11             Vellore         Tamil Nadu        coed             Vellore
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in X.columns:
    if X[col].dtypes == 'object':
        X[col] = le.fit_transform(X[col])

# %%
yk_ck = model.predict(X)

# %%
yk_ck
# Out:
# array([34.84468279, 35.56558264, 35.72794768, 36.21002634, 36.16639514,
#        36.63216962, 36.45094895, 36.88832348, 36.29065097, 37.47000073,
#        35.9699647 , 36.18322307, 36.81120971, 36.38151328, 34.46906156,
#        35.83971246, 35.27605979, 37.17983801, 36.74644123, 34.79713373,
#        35.82153055, 37.1526323 , 34.6779106 , 36.06196995, 37.10433634,
#        36.612763  , 37.50042691, 35.28117267, 35.6566518 , 35.08561083,
#        35.7367947 , 35.35561364, 36.91269829, 37.04874222, 36.22170413,
#        36.82048673, 34.42706784, 35.2096143 , 34.95503008, 35.81504823,
#        35.10013814, 36.82985503, 34.43537917, 37.27155196, 34.34717797,
#        34.37427268, 35.57303047, 35.44693779, 37.02525495, 36.85199898,
#        37.50771589])

# %%
dd_check_yk = pd.DataFrame((zip(l_check,yk_ck,gen)),
              columns=['Name','infra','gender'])

# %%
dd_check_yk
# Out:
#                                                  Name      infra gender
# 0               Indian Institute of Science Bangalore  34.844683   coed
# 1                         Jawaharlal Nehru University  35.565583   coed
# 2                            Banaras Hindu University  35.727948   coed
# 3                                 Jadavpur University  36.210026  women
# 4                                     Anna University  36.166395  women
# 5                             University of Hyderabad  36.632170   coed
# 6                                 University of Delhi  36.450949   coed
# 7                          Amrita Vishwa Vidyapeetham  36.888323  women
# 8                    Savitribai Phule Pune University  36.290651   coed
# 9                           Aligarh Muslim University  37.470001   coed
# 10                               Jamia Millia Islamia  35.969965   coed
# 11                    Vellore Institute of Technology  36.183223  women
# ...

# %%
dd_check_yk.sort_values(by=['infra'])
# Out:
#                                                  Name      infra gender
# 44          Guru Gobind Singh Indraprastha University  34.347178   coed
# 45  Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...  34.374273  women
# 36  Saveetha Institute of Medical and Technical Sc...  34.427068   coed
# 42                              University of Kashmir  34.435379   coed
# 14                                      Visva Bharati  34.469062   coed
# 22                                  Kerala University  34.677911   coed
# 19                                      Jamia Hamdard  34.797134   coed
# 0               Indian Institute of Science Bangalore  34.844683   coed
# 38                              Shiv Nadar University  34.955030   coed
# 29     Sathyabama Institute of Science and Technology  35.085611   coed
# 40                                University of Jammu  35.100138   coed
# 37                                 Calicut University  35.209614   coed
# ...

# %%
X
# Out:
#     City_2017  State_2017  gender_2017  City_2018  State_2018  infra_2017  \
# 0           5           5            0          5           5      100.00
# 1          24           3            0         23           3       46.28
# 2          34          15            0         33          15       43.62
# 3          20          16            0         18          16       35.50
# 4           9          13            0          8          13       63.22
# 5          17          14            0         15          14       21.66
# 6          13           3            0         12           3       33.15
# 7          12          13            0         11          13       31.44
# 8          26           7            0         25           7       15.04
# 9           1          15            1          1          15       26.30
# 10         24           3            1         23           3       11.76
# 11         35          13            0         34          13       36.71
# ...

# %%
import joblib

# %%
model=joblib.load(r"C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\dcr.sav")

# %%
d_pred = df_data_check

# %%
d_pred.drop('placements_2017',inplace=True,axis=1)
d_pred.drop('placements_2018',inplace=True,axis=1)
d_pred.drop('placements_2020',inplace=True,axis=1)
d_pred.drop('placements_2021',inplace=True,axis=1)
d_pred.drop('placements',inplace=True,axis=1)
d_pred.drop('academic_2017',inplace=True,axis=1)
d_pred.drop('academic_2018',inplace=True,axis=1)
d_pred.drop('academic',inplace=True,axis=1)
d_pred.drop('academic_2020',inplace=True,axis=1)
d_pred.drop('academic_2021',inplace=True,axis=1)

# %%
d_pred
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
d_pred.columns
# Out:
# Index(['Name', 'City_2017', 'State_2017', 'infra_2017', 'Year_2017',
#        'gender_2017', 'Rank_2017', 'City_2018', 'State_2018', 'infra_2018',
#        'Year_2018', 'gender_2018', 'Rank_2018', 'City', 'State', 'infra',
#        'Year', 'gender', 'Rank', 'City_2020', 'State_2020', 'infra_2020',
#        'Year_2020', 'gender_2020', 'Rank_2020', 'City_2021', 'State_2021',
#        'infra_2021', 'Year_2021', 'gender_2021', 'Rank_2021'],
#       dtype='object')

# %%
p=d_pred.head()
p
# Out:
#                                     Name  City_2017     State_2017  \
# 0  Indian Institute of Science Bangalore  Bengaluru      Karnataka
# 1            Jawaharlal Nehru University  New Delhi          Delhi
# 2               Banaras Hindu University   Varanasi  Uttar Pradesh
# 3                    Jadavpur University    Kolkata    West Bengal
# 4                        Anna University    Chennai     Tamil Nadu
#
#    infra_2017  Year_2017 gender_2017  Rank_2017  City_2018     State_2018  \
# 0       83.33       2017        coed          1  Bengaluru      Karnataka
# 1       47.27       2017        coed          2  New Delhi          Delhi
# 2       44.01       2017        coed          3   Varanasi  Uttar Pradesh
# 3       28.81       2017        coed          5    Kolkata    West Bengal
# 4       43.94       2017        coed          6    Chennai     Tamil Nadu
#
#    infra_2018  Year_2018 gender_2018  Rank_2018       City          State  \
# ...

# %%
dd_check_yk1 = pd.DataFrame((zip(l_check,yk_ck,gen)),
              columns=['Name','infra','gender'])

# %%
dd_check_yk1
# Out:
#                                                  Name      infra gender
# 0               Indian Institute of Science Bangalore  34.844683   coed
# 1                         Jawaharlal Nehru University  35.565583   coed
# 2                            Banaras Hindu University  35.727948   coed
# 3                                 Jadavpur University  36.210026  women
# 4                                     Anna University  36.166395  women
# 5                             University of Hyderabad  36.632170   coed
# 6                                 University of Delhi  36.450949   coed
# 7                          Amrita Vishwa Vidyapeetham  36.888323  women
# 8                    Savitribai Phule Pune University  36.290651   coed
# 9                           Aligarh Muslim University  37.470001   coed
# 10                               Jamia Millia Islamia  35.969965   coed
# 11                    Vellore Institute of Technology  36.183223  women
# ...

# %%
k=dd_check_yk1.sort_values(by=['infra'])

# %%
k
# Out:
#                                                  Name      infra gender
# 44          Guru Gobind Singh Indraprastha University  34.347178   coed
# 45  Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...  34.374273  women
# 36  Saveetha Institute of Medical and Technical Sc...  34.427068   coed
# 42                              University of Kashmir  34.435379   coed
# 14                                      Visva Bharati  34.469062   coed
# 22                                  Kerala University  34.677911   coed
# 19                                      Jamia Hamdard  34.797134   coed
# 0               Indian Institute of Science Bangalore  34.844683   coed
# 38                              Shiv Nadar University  34.955030   coed
# 29     Sathyabama Institute of Science and Technology  35.085611   coed
# 40                                University of Jammu  35.100138   coed
# 37                                 Calicut University  35.209614   coed
# ...

# %%
p=k.reset_index()
coed=p[p['gender']=='coed']
coed.sort_index()
coed=coed.drop('index',axis=1)
coed
# Out:
#                                                  Name      infra gender
# 0           Guru Gobind Singh Indraprastha University  34.347178   coed
# 2   Saveetha Institute of Medical and Technical Sc...  34.427068   coed
# 3                               University of Kashmir  34.435379   coed
# 4                                       Visva Bharati  34.469062   coed
# 5                                   Kerala University  34.677911   coed
# 6                                       Jamia Hamdard  34.797134   coed
# 7               Indian Institute of Science Bangalore  34.844683   coed
# 8                               Shiv Nadar University  34.955030   coed
# 9      Sathyabama Institute of Science and Technology  35.085611   coed
# 10                                University of Jammu  35.100138   coed
# 11                                 Calicut University  35.209614   coed
# 12   Bharath Institute of Higher Education & Research  35.276060   coed
# ...

# %%
q=coed.loc[:,"Name"]
q
# Out:
# 0             Guru Gobind Singh Indraprastha University
# 2     Saveetha Institute of Medical and Technical Sc...
# 3                                 University of Kashmir
# 4                                         Visva Bharati
# 5                                     Kerala University
# 6                                         Jamia Hamdard
# 7                 Indian Institute of Science Bangalore
# 8                                 Shiv Nadar University
# 9        Sathyabama Institute of Science and Technology
# 10                                  University of Jammu
# 11                                   Calicut University
# 12     Bharath Institute of Higher Education & Research
# 13                          Sri Venkateswara University
# 14                        North Eastern Hill University
# 15                                   Periyar University
# 16                          Jawaharlal Nehru University
# 17                                     NITTE University
# ...

# %%
list=q.head()

# %%
list
# Out:
# 0            Guru Gobind Singh Indraprastha University
# 2    Saveetha Institute of Medical and Technical Sc...
# 3                                University of Kashmir
# 4                                        Visva Bharati
# 5                                    Kerala University
# Name: Name, dtype: object

# %%
f = open(r"infra_coed.html",'w')

message = f'''<html><head><body><table><tr><td><a target=new_window href='http://ipu.ac.in/'>{list[0]}</a></td></tr><tr><td><a target=new_window href='https://www.saveetha.com/'>{list[2]}</a></td></tr><tr><td><a target=new_window href='https://www.kashmiruniversity.net/'>{list[3]}</a></td></tr><tr><td><a target=new_window href='https://www.visvabharati.ac.in/'>{list[4]}</a></td></tr><tr><td><a target=new_window href='https://www.keralauniversity.ac.in/'>{list[5]}</a></td></tr></table></body></head></html>'''
f.writelines(message)
f.close()

# %%
women=p[p['gender']=='women']
import numpy as np
n=women['Name'].count()
n
# Out:
# 10

# %%
women=women.drop('index',axis=1)
women
women=women.set_index(np.arange(n))
women
# Out:
#                                                 Name      infra gender
# 0  Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...  34.374273  women
# 1                    Dr. D. Y. Patil Vidyapeeth Pune  35.736795  women
# 2                                    Anna University  36.166395  women
# 3                    Vellore Institute of Technology  36.183223  women
# 4                                Jadavpur University  36.210026  women
# 5                           Bharathidasan University  36.851999  women
# 6                         Amrita Vishwa Vidyapeetham  36.888323  women
# 7                                   AMITY University  37.048742  women
# 8                                  Panjab University  37.104336  women
# 9                               University of Madras  37.500427  women

# %%
r=women.loc[:,"Name"]
l=r.head()
l
# Out:
# 0    Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...
# 1                      Dr. D. Y. Patil Vidyapeeth Pune
# 2                                      Anna University
# 3                      Vellore Institute of Technology
# 4                                  Jadavpur University
# Name: Name, dtype: object

# %%
f = open(r"infra_women.html",'w')

message = f'''<html><head><body><table><tr><td><a target=new_window href='http://mgmcri.ac.in/'>{l[0]}</a></td></tr><tr><td><a target=new_window href='https://dpu.edu.in/'>{l[1]}</a></td></tr><tr><td><a target=new_window href='https://www.annauniv.edu/'>{l[2]}</a></td></tr><tr><td><a target=new_window href='https://vit.ac.in/'>{l[3]}</a></td></tr><tr><td><a target=new_window href='http://www.jaduniv.edu.in/'>{l[4]}</a></td></tr></table></body></head></html>'''
f.writelines(message)
f.close()
