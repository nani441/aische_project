# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\project.csv')

# %%
df
# Out:
#        Institute ID                                               Name  \
# 0    IR17-I-2-18243              Indian Institute of Science Bangalore
# 1    IR17-I-2-1-319                        Jawaharlal Nehru University
# 2    IR17-I-2-18500                           Banaras Hindu University
# 3    IR17-I-2-30673  Jawaharlal Nehru Centre for Advanced Scientifi...
# 4    IR17-I-2-10326                                Jadavpur University
# ..              ...                                                ...
# 495     IR-O-U-0121                                     Goa University
# 496     IR-O-U-0043  Vignan's Foundation for Science, Technology an...
# 497     IR-O-U-0555                             Graphic Era University
# 498     IR-O-U-0223                                    Jain University
# 499     IR-O-U-0564         University of Petroleum and Energy Studies
#
#           City           State  infra  placements  academic  Year branch  \
# ...

# %%
df.describe()
# Out:
#             infra  placements    academic        Year        Rank
# count  500.000000  500.000000  500.000000   500.00000  500.000000
# mean    19.604140   70.248000   45.946420  2019.00000   50.500000
# std     17.372008   54.832287    8.060343     1.41563   28.894979
# min      0.000000    1.000000   32.990000  2017.00000    1.000000
# 25%      4.700000   27.000000   40.240000  2018.00000   25.750000
# 50%     16.585000   58.500000   44.065000  2019.00000   50.500000
# 75%     30.700000  100.000000   50.077500  2020.00000   75.250000
# max    100.000000  243.000000   84.180000  2021.00000  100.000000

# %%
df.isnull().sum()
# Out:
# Institute ID    0
# Name            0
# City            0
# State           0
# infra           0
# placements      0
# academic        0
# Year            0
# branch          0
# gender          0
# Rank            0
# dtype: int64

# %%
len_I = df['Institute ID'].unique()

# %%
len(len_I)
# Out:
# 324

# %%
list_N = df['Name'].unique()

# %%
len(list_N)
# Out:
# 177

# %%
df.drop('Institute ID',axis=1,inplace=True)

# %%
df.drop('branch',axis=1,inplace=True)

# %%
df
# Out:
#                                                   Name       City  \
# 0                Indian Institute of Science Bangalore  Bengaluru
# 1                          Jawaharlal Nehru University  New Delhi
# 2                             Banaras Hindu University   Varanasi
# 3    Jawaharlal Nehru Centre for Advanced Scientifi...  Bengaluru
# 4                                  Jadavpur University    Kolkata
# ..                                                 ...        ...
# 495                                     Goa University        Goa
# 496  Vignan's Foundation for Science, Technology an...     Guntur
# 497                             Graphic Era University   Dehradun
# 498                                    Jain University   Bengluru
# 499         University of Petroleum and Energy Studies   Dehradun
#
#               State  infra  placements  academic  Year gender  Rank
# 0         Karnataka  83.33           1     52.74  2017   coed     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        500 non-null    object
#  1   City        500 non-null    object
#  2   State       500 non-null    object
#  3   infra       500 non-null    float64
#  4   placements  500 non-null    int64
#  5   academic    500 non-null    float64
#  6   Year        500 non-null    int64
#  7   gender      500 non-null    object
#  8   Rank        500 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 35.3+ KB

# %%
df_2017 = df[df['Year']==2017]

# %%
df_2017
# Out:
#                                                  Name       City  \
# 0               Indian Institute of Science Bangalore  Bengaluru
# 1                         Jawaharlal Nehru University  New Delhi
# 2                            Banaras Hindu University   Varanasi
# 3   Jawaharlal Nehru Centre for Advanced Scientifi...  Bengaluru
# 4                                 Jadavpur University    Kolkata
# ..                                                ...        ...
# 95                     Sri Krishnadevaraya University  Anantapur
# 96                                Alagappa University  Karaikudi
# 97  Narsee Monjee Institute of Management Studies ...     Mumbai
# 98          Jawaharlal Nehru Technological University   Kakinada
# 99  B.S. Abdur Rahman Institute of Science and Tec...    Chennai
#
#              State  infra  placements  academic  Year gender  Rank
# 0        Karnataka  83.33           1     52.74  2017   coed     1
# ...

# %%
df_2018 = df[df['Year']==2018]

# %%
df_2018
# Out:
#                                                   Name        City  \
# 100              Indian Institute of Science Bangalore   Bengaluru
# 101                        Jawaharlal Nehru University   New Delhi
# 102                           Banaras Hindu University    Varanasi
# 103                                    Anna University     Chennai
# 104                            University of Hyderabad   Hyderabad
# ..                                                 ...         ...
# 195                          The University of Burdwan  Barddhaman
# 196                    D. Y. Patil Educational Society    Kolhapur
# 197  International Institute of Information Technology   Hyderabad
# 198                                     PES University   Bengaluru
# 199         Jaypee Institute of Information Technology       Noida
#
#              State   infra  placements  academic  Year gender  Rank
# 100      Karnataka  100.00           1     82.16  2018   coed     1
# ...

# %%
df_2019 = df[df['Year']==2019]

# %%
df_2019
# Out:
#                                                   Name         City  \
# 200              Indian Institute of Science Bangalore    Bengaluru
# 201                        Jawaharlal Nehru University    New Delhi
# 202                           Banaras Hindu University     Varanasi
# 203                            University of Hyderabad    Hyderabad
# 204                                Calcutta University      Kolkata
# ..                                                 ...          ...
# 295                       Central University of Punjab     Bathinda
# 296                           Assam University-Silchar      Silchar
# 297                             Kurukshetra University  Kurukshetra
# 298                            Rajiv Gandhi University     Itanagar
# 299  Meenakshi Academy of Higher Education and Rese...      Chennai
#
#                  State   infra  placements  academic  Year gender  Rank
# 200          Karnataka  100.00           1     82.28  2019   coed     1
# ...

# %%
df_2020 = df[df['Year']==2020]

# %%
df_2020
# Out:
#                                                   Name                  City  \
# 300              Indian Institute of Science Bangalore             Bengaluru
# 301                        Jawaharlal Nehru University             New Delhi
# 302                           Banaras Hindu University              Varanasi
# 303                         Amrita Vishwa Vidyapeetham            Coimbatore
# 304                                Jadavpur University               Kolkata
# ..                                                 ...                   ...
# 395                                   Utkal University           Bhubaneswar
# 396                             Graphic Era University              Dehradun
# 397        Chettinad Academy of Research and Education  Kanchipuram District
# 398                             Kurukshetra University           Kurukshetra
# 399  Vignan's Foundation for Science, Technology & ...                Guntur
#
# ...

# %%
df_2021 = df[df['Year']==2021]

# %%
df_2021
# Out:
#                                                   Name        City  \
# 400              Indian Institute of Science Bangalore   Bengaluru
# 401                        Jawaharlal Nehru University   New Delhi
# 402                           Banaras Hindu University    Varanasi
# 403                                Calcutta University     Kolkata
# 404                         Amrita Vishwa Vidyapeetham  Coimbatore
# ..                                                 ...         ...
# 495                                     Goa University         Goa
# 496  Vignan's Foundation for Science, Technology an...      Guntur
# 497                             Graphic Era University    Dehradun
# 498                                    Jain University    Bengluru
# 499         University of Petroleum and Energy Studies    Dehradun
#
#               State   infra  placements  academic  Year gender  Rank
# 400       Karnataka  100.00           1     82.67  2021  women     1
# ...

# %%
df_suffix = pd.merge(df_2017, df_2018, left_on='Name',right_on='Name',how='outer',suffixes=('_2017','_2018'))

df_suffix
# Out:
#                                                   Name  City_2017  \
# 0                Indian Institute of Science Bangalore  Bengaluru
# 1                          Jawaharlal Nehru University  New Delhi
# 2                             Banaras Hindu University   Varanasi
# 3    Jawaharlal Nehru Centre for Advanced Scientifi...  Bengaluru
# 4                                  Jadavpur University    Kolkata
# ..                                                 ...        ...
# 127                                           Yenepoya        NaN
# 128                                Nagaland University        NaN
# 129                          The University of Burdwan        NaN
# 130                    D. Y. Patil Educational Society        NaN
# 131  International Institute of Information Technology        NaN
#
#         State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0        Karnataka       83.33              1.0          52.74     2017.0
# ...

# %%
df_suffix.isna().sum()
# Out:
# Name                0
# City_2017          32
# State_2017         32
# infra_2017         32
# placements_2017    32
# academic_2017      32
# Year_2017          32
# gender_2017        32
# Rank_2017          32
# City_2018          32
# State_2018         32
# infra_2018         32
# placements_2018    32
# academic_2018      32
# Year_2018          32
# gender_2018        32
# Rank_2018          32
# dtype: int64

# %%
df_suffix['infra_2017'].describe()
# Out:
# count    100.000000
# mean      10.840900
# std       13.184734
# min        0.020000
# 25%        2.715000
# 50%        5.960000
# 75%       14.450000
# max       83.330000
# Name: infra_2017, dtype: float64

# %%
df_suffix['infra_2017'].fillna(14.5,inplace=True)

# %%
df_suffix['placements_2017'].describe()
# Out:
# count    100.000000
# mean      71.470000
# std       56.011986
# min        1.000000
# 25%       26.750000
# 50%       60.500000
# 75%      100.250000
# max      223.000000
# Name: placements_2017, dtype: float64

# %%
df_suffix['academic_2017'].describe()
# Out:
# count    100.000000
# mean      41.926300
# std        8.007775
# min       32.990000
# 25%       36.195000
# 50%       39.820000
# 75%       44.867500
# max       83.280000
# Name: academic_2017, dtype: float64

# %%
df_data = pd.merge(df_2017, df_2018, on='Name',suffixes=('_2017','_2018'))

# %%
df_data
# Out:
#                                            Name        City_2017  \
# 0         Indian Institute of Science Bangalore        Bengaluru
# 1                   Jawaharlal Nehru University        New Delhi
# 2                      Banaras Hindu University         Varanasi
# 3                           Jadavpur University          Kolkata
# 4                               Anna University          Chennai
# ..                                          ...              ...
# 63  Cochin University of Science and Technology           Cochin
# 64                     Bharathidasan University  Tiruchirappalli
# 65                     Assam University-Silchar          Silchar
# 66                               PES University        Bengaluru
# 67                          Alagappa University        Karaikudi
#
#        State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0       Karnataka       83.33                1          52.74       2017
# ...

# %%
df_data_1920 = pd.merge(df_data,df_2019,on='Name',suffixes=('','_2019'))

# %%
df_data_1920
# Out:
#                                            Name        City_2017  \
# 0         Indian Institute of Science Bangalore        Bengaluru
# 1                   Jawaharlal Nehru University        New Delhi
# 2                      Banaras Hindu University         Varanasi
# 3                           Jadavpur University          Kolkata
# 4                               Anna University          Chennai
# ..                                          ...              ...
# 59                           Periyar University            Salem
# 60  Cochin University of Science and Technology           Cochin
# 61                     Bharathidasan University  Tiruchirappalli
# 62                     Assam University-Silchar          Silchar
# 63                          Alagappa University        Karaikudi
#
#        State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0       Karnataka       83.33                1          52.74       2017
# ...

# %%
df_data_20 = pd.merge(df_data_1920,df_2020,on='Name',suffixes=('','_2020'))

# %%
df_data_20
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_20
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_check = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_check
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_21 = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_21
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_21.drop('Name',inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop(['Year_2017','Year_2018','Year_2020','Year_2021'],inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop('Year',inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
df_data_21.drop(['infra_2021','placements_2021','academic_2021'],inplace=True,axis=1)

# %%
df_data_21
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
X = df_data_21.drop('Rank_2021',axis=1)

# %%
X
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in X.columns:
    if X[col].dtypes == 'object':
        X[col] = le.fit_transform(X[col])

# %%
y = df_data_21['Rank_2020']

# %%
y
# Out:
# 0      1
# 1      2
# 2      3
# 3      5
# 4     12
# 5      6
# 6     11
# 7      4
# 8      9
# 9     17
# 10    10
# 11    16
# 12     7
# 13     8
# 14    50
# 15    14
# 16    59
# 17    29
# 18    18
# 19    21
# 20    47
# 21    13
# 22    23
# 23    40
# 24    26
# 25    58
# 26    22
# 27    38
# 28    19
# 29    39
# 30    46
# 31    49
# 32    24
# 33    37
# 34    55
# 35    63
# 36    42
# 37    54
# 38    56
# 39    70
# 40    52
# 41    82
# 42    48
# 43    51
# 44    95
# 45    88
# 46    74
# 47    83
# 48    62
# 49    53
# 50    36
# Name: Rank_2020, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,y, random_state=101, test_size=0.2)

# %%
X_train
# Out:
#     City_2017  State_2017  infra_2017  placements_2017  academic_2017  \
# 24          8           2       18.99               18          43.13
# 7          12          13       26.12               12          48.19
# 46         21           5        3.95               79          35.50
# 18         23           7       20.69               16          44.95
# 3          20          16       28.81                9          51.20
# 41          0          15       15.65               22          36.36
# 30         26           7       11.61               33          40.59
# 15         23           7        8.70               47          46.45
# 20         16           1        2.48              102          44.42
# 44         14           3        3.37               90          35.60
# 38         10          15        5.24               66          37.95
# 45         25          10        4.34               74          35.50
# ...

# %%
X_test
# Out:
#     City_2017  State_2017  infra_2017  placements_2017  academic_2017  \
# 37          7           6        4.74               68          38.45
# 14         20          16        4.71               69          54.70
# 21         12          13        9.11               45          44.29
# 32          6           9       20.95               14          40.47
# 22         31           6        0.89              132          43.95
# 1          24           3       47.27                3          51.75
# 26          9          13       10.82               40          41.85
# 47         27          13        5.85               61          35.44
# 43          2          11        4.65               71          35.83
# 48         11           6        1.89              109          35.42
# 16          9          13        3.79               84          46.45
#
#     gender_2017  Rank_2017  City_2018  State_2018  infra_2018  ...  City_2020  \
# ...

# %%
Y_train
# Out:
# 24    26
# 7      4
# 46    74
# 18    18
# 3      5
# 41    82
# 30    46
# 15    14
# 20    47
# 44    95
# 38    56
# 45    88
# 39    70
# 10    10
# 50    36
# 25    58
# 33    37
# 36    42
# 2      3
# 27    38
# 34    55
# 35    63
# 8      9
# 19    21
# 29    39
# 12     7
# 5      6
# 0      1
# 28    19
# 42    48
# 4     12
# 40    52
# 13     8
# 9     17
# 49    53
# 23    40
# 6     11
# 17    29
# 11    16
# 31    49
# Name: Rank_2020, dtype: int64

# %%
Y_test
# Out:
# 37    54
# 14    50
# 21    13
# 32    24
# 22    23
# 1      2
# 26    22
# 47    83
# 43    51
# 48    62
# 16    59
# Name: Rank_2020, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train_std = sc.fit_transform(X_train)

# %%
X_train_std
# Out:
# array([[-1.13699452, -1.28490984,  0.20029778, ..., -1.16853047,
#         -1.28490984, -0.69388867],
#        [-0.7244795 ,  0.84852537,  0.64690028, ..., -0.86169533,
#          0.84852537, -0.69388867],
#        [ 0.20367929, -0.70306388, -0.74176417, ...,  0.16108844,
#         -0.70306388, -0.69388867],
#        ...,
#        [-0.20883573,  1.04247402, -0.29015069, ..., -0.35030344,
#          1.04247402, -0.69388867],
#        [ 1.64748185,  0.84852537,  1.07471166, ...,  1.69526411,
#          0.84852537, -0.69388867],
#        [ 0.92558057, -0.12121791, -0.78623651, ...,  0.97931547,
#         -0.12121791, -0.69388867]])

# %%
X_test_std = sc.transform(X_test)

# %%
X_test_std
# Out:
# array([[-1.24012327, -0.50911522, -0.69228086,  0.40155519, -0.67792818,
#         -0.46056619,  0.67835283,  0.08399673, -0.50911522, -0.5913346 ,
#          0.05040831, -1.09578533, -0.42008403,  1.62217956,  0.05881007,
#         -0.50911522, -0.61989914,  0.12916299, -0.95040785, -0.53881591,
#          1.2495662 ,  0.05881007, -0.50911522, -0.97007872,  1.04686991,
#         -0.70000532, -0.53881591,  0.74636541,  0.05881007, -0.50911522,
#         -0.69388867],
#        [ 0.10055054,  1.43037133, -0.69415997,  0.42392596,  1.08376901,
#         -0.46056619, -0.72259323, -0.02099918,  1.43037133, -0.62909889,
#          0.19315752, -0.23330359, -0.42008403, -0.15903721,  0.87703709,
#          1.43037133, -0.40494712, -0.18906466, -0.48861585, -0.53881591,
#          0.12495662,  0.87703709,  1.43037133, -1.08339423,  1.60405758,
#         -0.64457104,  1.85592145,  0.58840447,  0.87703709,  1.43037133,
#         -0.69388867],
# ...

# %%
import joblib

# %%
joblib.dump(sc,r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\sc.sav')
# Out:
# ['C:\\Users\\Narasimha Reddy\\OneDrive\\Desktop\\sih\\model\\sc.sav']

# %%
X_train_std
# Out:
# array([[-1.13699452, -1.28490984,  0.20029778, ..., -1.16853047,
#         -1.28490984, -0.69388867],
#        [-0.7244795 ,  0.84852537,  0.64690028, ..., -0.86169533,
#          0.84852537, -0.69388867],
#        [ 0.20367929, -0.70306388, -0.74176417, ...,  0.16108844,
#         -0.70306388, -0.69388867],
#        ...,
#        [-0.20883573,  1.04247402, -0.29015069, ..., -0.35030344,
#          1.04247402, -0.69388867],
#        [ 1.64748185,  0.84852537,  1.07471166, ...,  1.69526411,
#          0.84852537, -0.69388867],
#        [ 0.92558057, -0.12121791, -0.78623651, ...,  0.97931547,
#         -0.12121791, -0.69388867]])

# %%
X_test_std
# Out:
# array([[-1.24012327, -0.50911522, -0.69228086,  0.40155519, -0.67792818,
#         -0.46056619,  0.67835283,  0.08399673, -0.50911522, -0.5913346 ,
#          0.05040831, -1.09578533, -0.42008403,  1.62217956,  0.05881007,
#         -0.50911522, -0.61989914,  0.12916299, -0.95040785, -0.53881591,
#          1.2495662 ,  0.05881007, -0.50911522, -0.97007872,  1.04686991,
#         -0.70000532, -0.53881591,  0.74636541,  0.05881007, -0.50911522,
#         -0.69388867],
#        [ 0.10055054,  1.43037133, -0.69415997,  0.42392596,  1.08376901,
#         -0.46056619, -0.72259323, -0.02099918,  1.43037133, -0.62909889,
#          0.19315752, -0.23330359, -0.42008403, -0.15903721,  0.87703709,
#          1.43037133, -0.40494712, -0.18906466, -0.48861585, -0.53881591,
#          0.12495662,  0.87703709,  1.43037133, -1.08339423,  1.60405758,
#         -0.64457104,  1.85592145,  0.58840447,  0.87703709,  1.43037133,
#         -0.69388867],
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([57.87, 47.16, 12.09, 34.57, 26.58,  4.12, 21.58, 79.03, 52.69,
#        64.3 , 48.12])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9519903493217484

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   City_2017        51 non-null     int32
#  1   State_2017       51 non-null     int32
#  2   infra_2017       51 non-null     float64
#  3   placements_2017  51 non-null     int64
#  4   academic_2017    51 non-null     float64
#  5   gender_2017      51 non-null     int32
#  6   Rank_2017        51 non-null     int64
#  7   City_2018        51 non-null     int32
#  8   State_2018       51 non-null     int32
#  9   infra_2018       51 non-null     float64
#  10  placements_2018  51 non-null     int64
#  11  academic_2018    51 non-null     float64
#  12  gender_2018      51 non-null     int32
#  13  Rank_2018        51 non-null     int64
#  14  City             51 non-null     int32
#  15  State            51 non-null     int32
#  16  infra            51 non-null     float64
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred_d = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred_d)
# Out:
# 0.9370954871885806

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, Y_train)
# Out:
# SVR()

# %%
y_pred_s = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, y_pred_s)
# Out:
# 0.2784113423133887

# %%
joblib.dump(regressor,r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\dcr.sav')
# Out:
# ['C:\\Users\\Narasimha Reddy\\OneDrive\\Desktop\\sih\\model\\dcr.sav']

# %%
model= joblib.load(r'C:\Users\Narasimha Reddy\OneDrive\Desktop\sih\model\dcr.sav')

# %%
model.predict(X_test)
# Out:
# array([39.88678946, 37.06228275, 27.81134073, 33.39984339, 36.66023419,
#        25.04317814, 28.68290213, 39.55311666, 38.07713488, 38.64893811,
#        38.92790328])

# %%
yy = model.predict(X)

# %%
from sklearn.metrics import r2_score
r2_score(y, yy)
# Out:
# 0.3190670392538486

# %%
model.predict(X)
# Out:
# array([28.78047536, 25.04317814, 25.29843156, 24.96364043, 25.51198345,
#        25.06894366, 25.22112911, 25.31635372, 26.87710165, 27.16016839,
#        28.70052524, 26.1858647 , 25.57280831, 25.57634002, 37.06228275,
#        31.91643028, 38.92790328, 31.22378856, 27.17547969, 37.3461984 ,
#        37.62013068, 27.81134073, 36.66023419, 31.7632911 , 27.86044537,
#        35.66037573, 28.68290213, 38.10000001, 29.51185322, 38.89999995,
#        37.24449473, 39.0436559 , 33.39984339, 35.99314011, 40.064123  ,
#        34.18541357, 39.11301265, 39.88678946, 39.65184805, 40.86087669,
#        40.40523306, 37.27306262, 39.20926317, 38.07713488, 39.17513851,
#        38.94553662, 40.64361627, 39.55311666, 38.64893811, 35.18807178,
#        33.49103601])

# %%
yk = model.predict(X)

# %%
yk
# Out:
# array([28.78047536, 25.04317814, 25.29843156, 24.96364043, 25.51198345,
#        25.06894366, 25.22112911, 25.31635372, 26.87710165, 27.16016839,
#        28.70052524, 26.1858647 , 25.57280831, 25.57634002, 37.06228275,
#        31.91643028, 38.92790328, 31.22378856, 27.17547969, 37.3461984 ,
#        37.62013068, 27.81134073, 36.66023419, 31.7632911 , 27.86044537,
#        35.66037573, 28.68290213, 38.10000001, 29.51185322, 38.89999995,
#        37.24449473, 39.0436559 , 33.39984339, 35.99314011, 40.064123  ,
#        34.18541357, 39.11301265, 39.88678946, 39.65184805, 40.86087669,
#        40.40523306, 37.27306262, 39.20926317, 38.07713488, 39.17513851,
#        38.94553662, 40.64361627, 39.55311666, 38.64893811, 35.18807178,
#        33.49103601])

# %%
l_check = df_data_check['Name'].tolist()

# %%
l_check

# %%
gen=df_data_check['gender'].tolist()

# %%
percentile_list = pd.DataFrame({'Name' : [l_check],
                                'Rank' : [yk],
                               'Gender':[gen]})

# %%
percentile_list
# Out:
#                                                 Name  \
# 0  [Indian Institute of Science Bangalore, Jawaha...
#
#                                                 Rank  \
# 0  [28.780475360410975, 25.04317813840092, 25.298...
#
#                                               Gender
# 0  [coed, coed, coed, women, women, coed, coed, w...

# %%
dd_check = pd.DataFrame(list(zip(l_check,yk,gen)),
              columns=['Name','Rank','gender'])

# %%
dd_check
# Out:
#                                                  Name       Rank gender
# 0               Indian Institute of Science Bangalore  28.780475   coed
# 1                         Jawaharlal Nehru University  25.043178   coed
# 2                            Banaras Hindu University  25.298432   coed
# 3                                 Jadavpur University  24.963640  women
# 4                                     Anna University  25.511983  women
# 5                             University of Hyderabad  25.068944   coed
# 6                                 University of Delhi  25.221129   coed
# 7                          Amrita Vishwa Vidyapeetham  25.316354  women
# 8                    Savitribai Phule Pune University  26.877102   coed
# 9                           Aligarh Muslim University  27.160168   coed
# 10                               Jamia Millia Islamia  28.700525   coed
# 11                    Vellore Institute of Technology  26.185865  women
# ...

# %%
dd_check.sort_values(by=['Rank'])
# Out:
#                                                  Name       Rank gender
# 3                                 Jadavpur University  24.963640  women
# 1                         Jawaharlal Nehru University  25.043178   coed
# 5                             University of Hyderabad  25.068944   coed
# 6                                 University of Delhi  25.221129   coed
# 2                            Banaras Hindu University  25.298432   coed
# 7                          Amrita Vishwa Vidyapeetham  25.316354  women
# 4                                     Anna University  25.511983  women
# 12                                Calcutta University  25.572808   coed
# 13        Manipal Academy of Higher Education-Manipal  25.576340   coed
# 11                    Vellore Institute of Technology  26.185865  women
# 8                    Savitribai Phule Pune University  26.877102   coed
# 9                           Aligarh Muslim University  27.160168   coed
# ...

# %%
df_data_ck = pd.merge(df_data_20,df_2021,on='Name',suffixes=('','_2021'))

# %%
df_data_ck
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
df_data_ck.drop(['Year_2017','Year_2018','Year_2020','Year_2021','Year'],inplace=True,axis=1)

# %%
df_data_ck
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
X=df_data_ck.drop('Name',axis=1)

# %%
X
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
X.columns
# Out:
# Index(['City_2017', 'State_2017', 'infra_2017', 'placements_2017',
#        'academic_2017', 'gender_2017', 'Rank_2017', 'City_2018', 'State_2018',
#        'infra_2018', 'placements_2018', 'academic_2018', 'gender_2018',
#        'Rank_2018', 'City', 'State', 'infra', 'placements', 'academic',
#        'gender', 'Rank', 'City_2020', 'State_2020', 'infra_2020',
#        'placements_2020', 'academic_2020', 'gender_2020', 'Rank_2020',
#        'City_2021', 'State_2021', 'infra_2021', 'placements_2021',
#        'academic_2021', 'gender_2021', 'Rank_2021'],
#       dtype='object')

# %%
df_data_21.columns
# Out:
# Index(['City_2017', 'State_2017', 'infra_2017', 'placements_2017',
#        'academic_2017', 'gender_2017', 'Rank_2017', 'City_2018', 'State_2018',
#        'infra_2018', 'placements_2018', 'academic_2018', 'gender_2018',
#        'Rank_2018', 'City', 'State', 'infra', 'placements', 'academic',
#        'gender', 'Rank', 'City_2020', 'State_2020', 'infra_2020',
#        'placements_2020', 'academic_2020', 'gender_2020', 'Rank_2020',
#        'City_2021', 'State_2021', 'gender_2021', 'Rank_2021'],
#       dtype='object')

# %%
X
# Out:
#              City_2017         State_2017  infra_2017  placements_2017  \
# 0            Bengaluru          Karnataka       83.33                1
# 1            New Delhi              Delhi       47.27                3
# 2             Varanasi      Uttar Pradesh       44.01                4
# 3              Kolkata        West Bengal       28.81                9
# 4              Chennai         Tamil Nadu       43.94                5
# 5            Hyderabad          Telangana       27.06               11
# 6                Delhi              Delhi       30.76                7
# 7           Coimbatore         Tamil Nadu       26.12               12
# 8                 Pune        Maharashtra       11.20               35
# 9              Aligarh      Uttar Pradesh       16.62               21
# 10           New Delhi              Delhi        9.73               42
# 11             Vellore         Tamil Nadu       32.95                6
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in X.columns:
    if X[col].dtypes == 'object':
        X[col] = le.fit_transform(X[col])

# %%
d_pred = df_data_check

# %%
d_pred
# Out:
#                                                  Name           City_2017  \
# 0               Indian Institute of Science Bangalore           Bengaluru
# 1                         Jawaharlal Nehru University           New Delhi
# 2                            Banaras Hindu University            Varanasi
# 3                                 Jadavpur University             Kolkata
# 4                                     Anna University             Chennai
# 5                             University of Hyderabad           Hyderabad
# 6                                 University of Delhi               Delhi
# 7                          Amrita Vishwa Vidyapeetham          Coimbatore
# 8                    Savitribai Phule Pune University                Pune
# 9                           Aligarh Muslim University             Aligarh
# 10                               Jamia Millia Islamia           New Delhi
# 11                    Vellore Institute of Technology             Vellore
# ...

# %%
c=d_pred.head()
c
# Out:
#                                     Name  City_2017     State_2017  \
# 0  Indian Institute of Science Bangalore  Bengaluru      Karnataka
# 1            Jawaharlal Nehru University  New Delhi          Delhi
# 2               Banaras Hindu University   Varanasi  Uttar Pradesh
# 3                    Jadavpur University    Kolkata    West Bengal
# 4                        Anna University    Chennai     Tamil Nadu
#
#    infra_2017  placements_2017  academic_2017  Year_2017 gender_2017  \
# 0       83.33                1          52.74       2017        coed
# 1       47.27                3          51.75       2017        coed
# 2       44.01                4          51.46       2017        coed
# 3       28.81                9          51.20       2017        coed
# 4       43.94                5          48.90       2017        coed
#
#    Rank_2017  City_2018  ... gender_2020  Rank_2020  City_2021     State_2021  \
# ...

# %%
d=c.loc[:,"Name"]
d
# Out:
# 0    Indian Institute of Science Bangalore
# 1              Jawaharlal Nehru University
# 2                 Banaras Hindu University
# 3                      Jadavpur University
# 4                          Anna University
# Name: Name, dtype: object

# %%
list2=[]
for i in range(0,5):
    list2.append(d[i])

# %%
f = open(r"overall.html",'w')

message = f'''<html><head><body><table><tr><td><a target=new_window href='https://iisc.ac.in/'>{list2[0]}</a></td></tr><tr><td><a target=new_window href='https://www.jnu.ac.in/'>{list2[1]}</a></td></tr><tr><td><a target=new_window href='http://www.bhu.ac.in/'>{list2[2]}</a></td></tr><tr><td><a target=new_window href='http://www.jaduniv.edu.in/'>{list2[3]}</a></td></tr><tr><td><a target=new_window href='https://www.annauniv.edu/'>{list2[4]}</a></td></tr></table></body></head></html>'''
f.writelines(message)
f.close()

# %%
p=d_pred.reset_index()
coed=p[p['gender']=='coed']
coed.sort_index()
coed=coed.drop('index',axis=1)
coed.head()
# Out:
#                                     Name  City_2017     State_2017  \
# 0  Indian Institute of Science Bangalore  Bengaluru      Karnataka
# 1            Jawaharlal Nehru University  New Delhi          Delhi
# 2               Banaras Hindu University   Varanasi  Uttar Pradesh
# 5                University of Hyderabad  Hyderabad      Telangana
# 6                    University of Delhi      Delhi          Delhi
#
#    infra_2017  placements_2017  academic_2017  Year_2017 gender_2017  \
# 0       83.33                1          52.74       2017        coed
# 1       47.27                3          51.75       2017        coed
# 2       44.01                4          51.46       2017        coed
# 5       27.06               11          48.84       2017        coed
# 6       30.76                7          48.27       2017        coed
#
#    Rank_2017  City_2018  ... gender_2020  Rank_2020  City_2021     State_2021  \
# ...

# %%
co=coed.loc[:,"Name"]
co=co.head()
co
# Out:
# 0    Indian Institute of Science Bangalore
# 1              Jawaharlal Nehru University
# 2                 Banaras Hindu University
# 5                  University of Hyderabad
# 6                      University of Delhi
# Name: Name, dtype: object

# %%
f = open(r"overall_coed.html",'w')

message = f'''<html><head><body baqckground="" height=100% width=100%><table><tr><td><font size="100px"><a target=new_window href='https://iisc.ac.in/' color="white">{co[0]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='https://www.jnu.ac.in/' color="white">{co[1]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='http://www.bhu.ac.in/' color="white">{co[2]}</a></font></td></tr><tr><td><a target=new_window href='https://uohyd.ac.in/' color="white">{co[5]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='http://www.du.ac.in/' color="white">{co[6]}</a></font></td></tr></table></body></head></html>'''
f.writelines(message)
f.close()

# %%
women=p[p['gender']=='women']
import numpy as np
n=women['Name'].count()
n
# Out:
# 10

# %%
women=women.drop('index',axis=1)
women
women=women.set_index(np.arange(n))
women
# Out:
#                                                 Name          City_2017  \
# 0                                Jadavpur University            Kolkata
# 1                                    Anna University            Chennai
# 2                         Amrita Vishwa Vidyapeetham         Coimbatore
# 3                    Vellore Institute of Technology            Vellore
# 4                                  Panjab University         Chandigarh
# 5                               University of Madras            Chennai
# 6                    Dr. D. Y. Patil Vidyapeeth Pune               Pune
# 7                                   AMITY University  Gautam Budh Nagar
# 8  Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...         Puducherry
# 9                           Bharathidasan University    Tiruchirappalli
#
#       State_2017  infra_2017  placements_2017  academic_2017  Year_2017  \
# 0    West Bengal       28.81                9          51.20       2017
# ...

# %%
women=women.loc[:,"Name"]
women.tail()
# Out:
# 5                                 University of Madras
# 6                      Dr. D. Y. Patil Vidyapeeth Pune
# 7                                     AMITY University
# 8    Sri Balaji Vidyapeeth Mahatma Gandhi Medical C...
# 9                             Bharathidasan University
# Name: Name, dtype: object

# %%
f = open(r"overall_women.html",'w')

message = f'''<html><head> </head><body background="" height=100% width=-100%><center><table><tr><td><font size="100px"><a target=new_window href='https://www.unom.ac.in/' color="white">{women[5]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='https://dpu.edu.in/' color="white">{women[6]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='https://www.amity.edu/' color="white">{women[7]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='http://mgmcri.ac.in/' color="white">{women[8]}</a></font></td></tr><tr><td><font size="100px"><a target=new_window href='https://www.bdu.ac.in/' color="white">{women[9]}</a></font></td></tr></table></center></body></html>'''
f.writelines(message)
f.close()
